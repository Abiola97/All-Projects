# %% [markdown]
# <a href="https://colab.research.google.com/github/Abiola97/All-Projects/blob/main/Investment_Data_Analysis_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **TASK 01: Data Overview**

# %% [markdown]
# **Objective: Understanding the dataset structure.**

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
investment_data = pd.read_excel('/content/Investment Dataset.xlsx')

investment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %% [markdown]
# ## **Task 02: Gender Distribution**

# %% [markdown]
# **Objective: Extracting and Visualize gender distribution in
# the dataset.**

# %%
# Assuming 'Gender' is the column name for gender information.
gender_column = investment_data['gender']
gender_column.head()
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# Name: gender, dtype: object

# %%
import matplotlib.pyplot as plt
# Assuming 'Gender' is the column name for gender information
gender_counts = investment_data['gender'].value_counts()

# Pie chart
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')  # Remove the y-axis label for pie charts
plt.show()

# %% [markdown]
# ##**Task 03: Descriptive Statistics**

# %% [markdown]
# **Objective: Present basic statistics for
# numerical columns.**

# %%
# Identify numerical columns
numerical_cols = investment_data.select_dtypes(include=['number'])

# Display numerical columns
print("Numerical Columns:")
numerical_cols.columns
# Out:
# Numerical Columns:
# Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %%
# Calculate mean, median, and standard deviation for each numerical column
numerical_stats = numerical_cols.agg(['mean', 'median', 'std'])

# Display the calculated statistics
print("\nDescriptive Statistics for Numerical Columns:")
numerical_stats
# Out:
# Descriptive Statistics for Numerical Columns:
#               age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# mean    27.800000      2.550000       3.475000    5.750000          4.650000
# median  27.000000      2.000000       4.000000    6.500000          5.000000
# std      3.560467      1.197219       1.131994    1.675617          1.369072
#
#         Fixed_Deposits       PPF      Gold
# mean          3.575000  2.025000  5.975000
# median        3.500000  1.000000  6.000000
# std           1.795828  1.609069  1.143263

# %% [markdown]
# ### **Task 4: Most Preferred Investment Avenue**

# %% [markdown]
# **Identify the most preferred investment avenue**

# %%
# Assuming 'Investment Avenue' is the column name for investment information.
investment_avenue_column = investment_data['Avenue']

# Count the occurrences of each investment avenue
investment_counts = investment_avenue_column.value_counts()

# Display the counts
print("\nInvestment Avenue Counts:")
print(investment_counts)

# Bar chart of investment avenues
plt.figure(figsize=(10, 6))
investment_counts.plot(kind='bar')
plt.title('Distribution of Investment Avenues')
plt.xlabel('Investment Avenue')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# The investment avenue with the highest frequency
most_frequent_investment = investment_counts.idxmax()
print(f"\nThe most frequent investment avenue is: {most_frequent_investment}")
# Out:
# Investment Avenue Counts:
# Avenue
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: count, dtype: int64
# The most frequent investment avenue is: Mutual Fund

# %% [markdown]
# ## **Task 5: Reasons for Investment**

# %% [markdown]
# **Objective: Analyze and summarize reasons for investment choices.**

# %%
# Assuming 'Reasons' is the column name for investment reasons.
reasons_column = investment_data['Reason_Mutual']
reasons_column1 = investment_data['Reason_Equity']
reasons_column2 = investment_data['Reason_Bonds']
reasons_column3 = investment_data['Reason_FD']

# Count the occurrences of each reason
reason_counts = reasons_column.value_counts()
reason_counts1 = reasons_column1.value_counts()
reason_counts2 = reasons_column2.value_counts()
reason_counts3 = reasons_column3.value_counts()

# Display the counts
print("\nReasons for Mutual Investment Counts:")
print(reason_counts)

print("\nReasons for Equity Counts:")
print(reason_counts1)

print("\nReasons for Bonds Investment Counts:")
print(reason_counts2)

print("\nReasons for Fixed Deposit Investment Counts:")
print(reason_counts3)

# Bar chart of reasons for Mutual Investment
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
reason_counts.plot(kind='bar')
plt.title('Distribution of Reasons for Mutual Investment')
plt.xlabel('Reason for Investment')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# Bar chart of reasons for Equity Investment
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
reason_counts1.plot(kind='bar')
plt.title('Distribution of Reasons for Equity Investment')
plt.xlabel('Reason for Investment')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# Bar chart of reasons for Bonds Investment
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
reason_counts2.plot(kind='bar')
plt.title('Distribution of Reasons for Bonds Investment')
plt.xlabel('Reason for Bonds Investment')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()


# Bar chart of reasons for Bonds Investment
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
reason_counts3.plot(kind='bar')
plt.title('Distribution of Reasons for Fixed Deposit Investment ')
plt.xlabel('Reason for Fixed Deposit Investment ')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# Reasons for Mutual Investment Counts:
# Reason_Mutual
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: count, dtype: int64
#
# Reasons for Equity Counts:
# Reason_Equity
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: count, dtype: int64
#
# Reasons for Bonds Investment Counts:
# Reason_Bonds
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: count, dtype: int64
#
# Reasons for Fixed Deposit Investment Counts:
# Reason_FD
# Risk Free              19
# Fixed Returns          18
# High Interest Rates     3
# Name: count, dtype: int64

# %% [markdown]
# ## **Task 6: Savings Objectives**

# %% [markdown]
# **Objective: Identify and present main savings objectives.**

# %%
# Assuming 'Savings Objective' is the column name for savings objectives.
savings_objectives_column = investment_data['Objective']

# Count the occurrences of each savings objective
savings_objective_counts = savings_objectives_column.value_counts()

# Display the counts
print("\nSavings Objectives Counts:")
print(savings_objective_counts)

# Bar chart of savings objectives
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
savings_objective_counts.plot(kind='bar')
plt.title('Distribution of Savings Objectives')
plt.xlabel('Savings Objective')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# Savings Objectives Counts:
# Objective
# Capital Appreciation    26
# Growth                  11
# Income                   3
# Name: count, dtype: int64

# %%
# Assuming 'Savings Objective' is the column name for savings objectives.
savings_objectives_column = investment_data['Objective']

# Count the occurrences of each savings objective
savings_objective_counts = savings_objectives_column.value_counts()

# Display the counts
print("\nSavings Objectives Counts:")
print(savings_objective_counts)

# Describe the objectives (you can customize this based on your analysis)
print("\nDescription of Savings Objectives:")
for objective, count in savings_objective_counts.items():
  print(f"- {objective}: {count} participants mentioned this objective.")
  # Add more detailed description if needed, e.g., based on other data analysis.
# Out:
# Savings Objectives Counts:
# Objective
# Capital Appreciation    26
# Growth                  11
# Income                   3
# Name: count, dtype: int64
#
# Description of Savings Objectives:
# - Capital Appreciation: 26 participants mentioned this objective.
# - Growth: 11 participants mentioned this objective.
# - Income: 3 participants mentioned this objective.

# %% [markdown]
# ## **Task 7: Common Information Sources**

# %% [markdown]
# **Objective: Analyze common sources participants rely on for investment information.**

# %%
# Assuming 'Source' is the column name for source of information for customers to make investment.
source_column = investment_data['Source']

# Count the occurrences of each source
source_column_counts = source_column.value_counts()

# Display the counts
print("\nSource of Information Counts:")
print(source_column_counts)

# Bar chart of source of information
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization
source_column_counts.plot(kind='bar')
plt.title('Distribution of Source of Information')
plt.xlabel('Source of information')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# Source of Information Counts:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %% [markdown]
# **From the visualization, the most common source of information for investement is Financial Consulatants.**

# %% [markdown]
# ## **Task 8: Investment Duration**

# %% [markdown]
# **Objective: Analyze Investment Duration Column. Calculate the average investment duration.**

# %%
# Assuming 'Duration' is the column name for investment duration.
duration_column = investment_data['Duration']

# Analyze as categorical data
duration_counts = duration_column.value_counts()
print(f"\nInvestment Duration Counts (categorical):\n{duration_counts}")

# Bar chart of categorical duration
plt.figure(figsize=(12,6))
duration_counts.plot(kind='bar')
plt.title("Distribution of Investment Duration (Categorical)")
plt.xlabel('Investment Duration')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Investment Duration Counts (categorical):
# Duration
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: count, dtype: int64

# %% [markdown]
# **From the barplot, the majority of the investment duration is 3-5 years.**

# %% [markdown]
# # **Task 9: Expectations from Investments**

# %% [markdown]
# **Objective: Most Common Expectation mentioned by participants.**

# %%
# Assuming 'Expectations' is the column name for participant expectations.
expectations_column = investment_data['Expect']

# Count the occurrences of each expectation
expectation_counts = expectations_column.value_counts()

# Display the counts
print("\nExpectations Counts:")
print(expectation_counts)

# Describe the expectations (you can customize this based on your analysis)
print("\nDescription of Expectations:")
for expectation, count in expectation_counts.items():
    print(f"- {expectation}: {count} participants mentioned this expectation.")
    # Add more detailed description if needed, e.g., based on other data analysis.

# Bar chart of Expectation column
plt.figure(figsize=(12, 6))
expectation_counts.plot(kind='bar') # Changed expectations_column_counts to expectation_counts
plt.title("Distribution of Expectation")
plt.xlabel('Expectation')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Expectations Counts:
# Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64
#
# Description of Expectations:
# - 20%-30%: 32 participants mentioned this expectation.
# - 30%-40%: 5 participants mentioned this expectation.
# - 10%-20%: 3 participants mentioned this expectation.

# %% [markdown]
# **From the visualization above, most particpants expect 20-30% Return on Investement.**

# %% [markdown]
# ### **Task 10: Correlation Analysis**

# %% [markdown]
# **Objective: Establish the most correlated factors driving Investment**

# %%
# Select relevant columns for correlation analysis
# Treating 'Duration' and 'Expect' as categorical, we'll use a different approach than Pearson correlation
selected_columns = investment_data[['age', 'Duration', 'Expect']]

# Convert 'Duration' and 'Expect' to categorical data type if not already
selected_columns['Duration'] = selected_columns['Duration'].astype('category')
selected_columns['Expect'] = selected_columns['Expect'].astype('category')

# Analyze relationships between 'age' and categorical variables using groupby and describe
print("\nRelationship between Age and Duration:")
print(selected_columns.groupby('Duration')['age'].describe())

print("\nRelationship between Age and Expected Return:")
print(selected_columns.groupby('Expect')['age'].describe())

# Visualize the relationship between age and other factors (categorical) using box plots
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
selected_columns.boxplot(column='age', by='Duration', rot=45)  # Rotate x-axis labels
plt.title('Age vs. Duration')
plt.xlabel('Duration')  # Add x-axis label
plt.ylabel('Age')  # Add y-axis label

plt.subplot(1, 2, 2)
selected_columns.boxplot(column='age', by='Expect', rot=45)  # Rotate x-axis labels
plt.title('Age vs. Expected Return')
plt.xlabel('Expected Return') # Add x-axis label
plt.ylabel('Age') # Add y-axis label

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3687440875.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns['Duration'] = selected_columns['Duration'].astype('category')
# /tmp/ipython-input-3687440875.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns['Expect'] = selected_columns['Expect'].astype('category')
# ...
